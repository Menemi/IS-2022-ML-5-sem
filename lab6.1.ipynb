# %% [markdown]
# # Обучение нейрона с помощью функции потерь LogLoss

# %% [markdown]
# ###Нейрон с сигмоидой

# %% [markdown]
# Снова рассмотрим нейрон с сигмоидой, то есть $$f(x) = \sigma(x)=\frac{1}{1+e^{-x}}$$

# %% [markdown]
# Ранее мы установили, что **обучение нейрона с сигмоидой с квадратичной функцией потерь**:
#
# $$MSE(w, x) = \frac{1}{2n}\sum_{i=1}^{n} (\hat{y_i} - y_i)^2 = \frac{1}{2n}\sum_{i=1}^{n} (\sigma(w \cdot x_i) - y_i)^2$$
#
# где $w \cdot x_i$ - скалярное произведение, а $\sigma(w \cdot x_i) =\frac{1}{1+e^{-w \cdot x_i}} $ - сигмоида -- **неэффективно**, то есть мы увидели, что даже за большое количество итераций нейрон предсказывает плохо.

# %% [markdown]
# Давайте ещё раз взглянем на формулу для градиентного спуска от функции потерь $MSE$ по весам нейрона:

# %% [markdown]
# $$ \frac{\partial MSE}{\partial w} = \frac{1}{n} X^T (\sigma(w \cdot X) - y)\sigma(w \cdot X)(1 - \sigma(w \cdot X))$$

# %% [markdown]
# А теперь смотрим на график сигмоиды:

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/1200/1*IDAnCFoeXqWL7F4u9MJMtA.png" width=500px height=350px>

# %% [markdown]
# **Её значения: числа от 0 до 1.**

# %% [markdown]
# Если получше проанализировать формулу, то теперь можно заметить, что, поскольку сигмоида принимает значения между 0 и 1 (а значит (1-$\sigma$) тоже принимает значения от 0 до 1), то мы умножаем $X^T$ на столбец $(\sigma(w \cdot X) - y)$ из чисел от -1 до 1, а потом ещё на столбцы $\sigma(w \cdot X)$ и $(1 - \sigma(w \cdot X))$ из чисел от 0 до 1. Таким образом в лучшем случае $\frac{\partial{Loss}}{\partial{w}}$ будет столбцом из чисел, порядок которых максимум 0.01 (в среднем, понятно, что если сигмоида выдаёт все 0, то будет 0, если все 1, то тоже 0). После этого мы умножаем на шаг градиентного спуска, который обычно порядка 0.001 или 0.1 максимум. То есть мы вычитаем из весов числа порядка ~0.0001. Медленновато спускаемся, не правда ли? Это называют **проблемой затухающих градиентов**.

# %% [markdown]
# Чтобы избежать эту проблему в задачах классификации, в которых моделью является нейрон с сигмоидной функцией активации, предсказывающий "вероятности" принадлженостей к классам используют **LogLoss**:

# %% [markdown]
# $$J(\hat{y}, y) = -\frac{1}{n} \sum_{i=1}^n y_i \log(\hat{y_i}) + (1 - y_i) \log(1 - \hat{y_i}) = -\frac{1}{n} \sum_{i=1}^n y_i \log(\sigma(w \cdot x_i)) + (1 - y_i) \log(1 - \sigma(w \cdot x_i))$$

# %% [markdown]
# где, как и прежде, $y$ - столбец $(n, 1)$ из истинных значений классов, а $\hat{y}$ - столбец $(n, 1)$ из предсказаний нейрона.

# %%
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import pandas as pd

# %%
def loss(y_pred, y):
    return -np.mean(y * np.log(y_pred) + (1 - y) * np.log(1 - y_pred))

# %% [markdown]
# Отметим, что сейчас речь идёт именно о **бинарной классификации (на два класса)**, в многоклассовой классификации используется функция потерь под названием *кросс-энтропия*, которая является обобщением LogLoss'а на случай нескольких классов.

# %% [markdown]
# Почему же теперь всё будет лучше? Раньше была проблема умножения маленьких чисел в градиенте. Давайте посмотрим, что теперь:

# %% [markdown]
# * Для веса $w_j$:

# %% [markdown]
# $$ \frac{\partial Loss}{\partial w_j} =
# -\frac{1}{n} \sum_{i=1}^n \left(\frac{y_i}{\sigma(w \cdot x_i)} - \frac{1 - y_i}{1 - \sigma(w \cdot x_i)}\right)(\sigma(w \cdot x_i))_{w_j}' = -\frac{1}{n} \sum_{i=1}^n \left(\frac{y_i}{\sigma(w \cdot x_i)} - \frac{1 - y_i}{1 - \sigma(w \cdot x_i)}\right)\sigma(w \cdot x_i)(1 - \sigma(w \cdot x_i))x_{ij} = $$
# $$-\frac{1}{n} \sum_{i=1}^n \left(y_i - \sigma(w \cdot x_i)\right)x_{ij}$$

# %% [markdown]
# * Градиент $Loss$'а по вектору весов -- это вектор, $j$-ая компонента которого равна $\frac{\partial Loss}{\partial w_j}$ (помним, что весов всего $m$):

# %% [markdown]
# $$\begin{align}
#     \frac{\partial Loss}{\partial w} &= \begin{bmatrix}
#            -\frac{1}{n} \sum_{i=1}^n \left(y_i - \sigma(w \cdot x_i)\right)x_{i1} \\
#            -\frac{1}{n} \sum_{i=1}^n \left(y_i - \sigma(w \cdot x_i)\right)x_{i2} \\
#            \vdots \\
#            -\frac{1}{n} \sum_{i=1}^n \left(y_i - \sigma(w \cdot x_i)\right)x_{im}
#          \end{bmatrix}
# \end{align}=\frac{1}{n} X^T \left(\hat{y} - y\right)$$

# %% [markdown]
# По аналогии с $w_j$ выведите формулу для свободного члена (bias'а) $b$ (*hint*: можно считать, что при нём есть признак $x_{i0}=1$ на всех $i$).

# %% [markdown]
# $$\begin{align}
#     \frac{\partial Loss}{\partial b} &= \begin{bmatrix}
#            -\frac{1}{n} \sum_{i=1}^n \left(y_i - \sigma(w \cdot x_i)\right)x_{i1} \\
#            -\frac{1}{n} \sum_{i=1}^n \left(y_i - \sigma(w \cdot x_i)\right)x_{i2} \\
#            \vdots \\
#            -\frac{1}{n} \sum_{i=1}^n \left(y_i - \sigma(w \cdot x_i)\right)x_{im}
#          \end{bmatrix}
# \end{align}=\frac{1}{n} X^T \left(\hat{y} - y\right)$$

# %% [markdown]
# Получили новое правило для обновления $w$ и $b$.

# %%
def sigmoid(x):
    """Сигмоидальная функция"""
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# Реализуйте нейрон с функцией потерь LogLoss:

# %%
class Neuron:
    
    def __init__(self, w=None, b=0):
        """
        :param: w -- вектор весов
        :param: b -- смещение
        """
        # пока что мы не знаем размер матрицы X, а значит не знаем, сколько будет весов
        self.w = w
        self.b = b
        
        
    def activate(self, x):
        return sigmoid(x)
    
        
    def forward_pass(self, X):
        """
        Эта функция рассчитывает ответ нейрона при предъявлении набора объектов
        :param: X -- матрица объектов размера (n, m), каждая строка - отдельный объект
        :return: вектор размера (n, 1) из нулей и единиц с ответами перцептрона 
        """
        y_pred = self.activate(np.dot(X, self.w) + self.b)
        return y_pred
        
    def predict(self, X):
        return np.round(self.forward_pass(X))
    
    def backward_pass(self, X, y, y_pred, learning_rate=0.1):
        """
        Обновляет значения весов нейрона в соответствие с этим объектом
        :param: X -- матрица объектов размера (n, m)
                y -- вектор правильных ответов размера (n, 1)
                learning_rate - "скорость обучения" (символ alpha в формулах выше)
        В этом методе ничего возвращать не нужно, только правильно поменять веса
        с помощью градиентного спуска.
        """
        y = np.array(y).reshape(-1, 1)
        sigma = self.activate(X @ self.w + self.b)
        self.w = self.w - learning_rate * (X.T @ ((sigma - y) * sigma * (1 - sigma))) / len(y)
        self.b = self.b - learning_rate * np.mean((sigma - y) * sigma * (1 - sigma))
        
    
    def fit(self, X, y, num_epochs=5000):
        """
        Спускаемся в минимум
        :param: X -- матрица объектов размера (n, m)
                y -- вектор правильных ответов размера (n, 1)
                num_epochs -- количество итераций обучения
        :return: J_values -- вектор значений функции потерь
        """
        self.w = np.zeros((X.shape[1], 1))  # столбец (m, 1)
        self.b = 0  # смещение
        loss_values = []  # значения функции потерь на различных итерациях обновления весов
        
        for i in range(num_epochs):
            # предсказания с текущими весами
            y_pred = self.forward_pass(X)
            # считаем функцию потерь с текущими весами
            loss_values.append(loss(y_pred, y))
            # обновляем веса по формуле градиентного спуска
            self.backward_pass(X, y, y_pred)

        return loss_values

# %% [markdown]
# ###Тестирование

# %% [markdown]
# Протестируем нейрон, обученный с новой функцией потерь, на тех же данных, что и в предыдущем ноутбуке:

# %% [markdown]
# **Проверка forward_pass()**

# %%
w = np.array([1., 2.]).reshape(2, 1)
b = 2.
X = np.array([[1., 3.],
              [2., 4.],
              [-1., -3.2]])

neuron = Neuron(w, b)
y_pred = neuron.forward_pass(X)
print ("y_pred = " + str(y_pred))
# Out:
# y_pred = [[0.99987661]
#  [0.99999386]
#  [0.00449627]]

# %% [markdown]
# **Проверка backward_pass()**

# %%
y = np.array([1, 0, 1]).reshape(3, 1)

# %%
neuron.backward_pass(X, y, y_pred)

print ("w = " + str(neuron.w))
print ("b = " + str(neuron.b))
# Out:
# w = [[0.99985106]
#  [1.99952388]]
# b = 2.000148326741343

# %% [markdown]
# Проверьте на наборах данных "яблоки и груши" и "голос".

# %% [markdown]
# #### Яблоки и груши

# %%
from google.colab import drive
drive.mount('/content/drive')

data = pd.read_csv('/content/drive/MyDrive/ML/apples_pears.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=data['target'], cmap='rainbow')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('Симметричность', fontsize=14)
plt.ylabel('Желтизна', fontsize=14)
plt.show();

# %%
X = data.iloc[:,:2].values
y = data['target'].values.reshape((-1, 1))

# %%
# %%time

neuron = Neuron()
Loss_values = neuron.fit(X, y)

plt.figure(figsize=(10, 8))
plt.plot(Loss_values)
plt.title('Функция потерь', fontsize=15)
plt.xlabel('номер итерации', fontsize=14)
plt.ylabel('Loss(y^, y)', fontsize=14)
plt.show()
# Out:
# CPU times: user 1.2 s, sys: 5.22 ms, total: 1.2 s
# Wall time: 1.22 s

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=np.array(neuron.forward_pass(X) > 0.5).ravel(), cmap='rainbow')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('Симметричность', fontsize=14)
plt.ylabel('Желтизна', fontsize=14)
plt.show();

# %%
# %%time

neuron = Neuron()
loss_values = neuron.fit(X, y, num_epochs=100000)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=np.array(neuron.forward_pass(X) > 0.5).ravel(), cmap='rainbow')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('Симметричность', fontsize=14)
plt.ylabel('Желтизна', fontsize=14)
plt.show();
# Out:
# CPU times: user 20.3 s, sys: 14.9 ms, total: 20.3 s
# Wall time: 20.4 s

# %% [markdown]
# #### Голос

# %%
import pandas as pd
from sklearn.linear_model import Perceptron as skPerceptron
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("/content/drive/MyDrive/ML/voice.csv")
data['label'] = data['label'].apply(lambda x: 1 if x == 'male' else 0)
data
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
#              kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0      274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1      634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2     1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3        4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4        4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
# ...           ...       ...       ...  ...       ...       ...       ...
# 3163     6.630383  0.962934  0.763182  ...  0.131884  0.182790  0.083770
# 3164     2.503954  0.960716  0.709570  ...  0.116221  0.188980  0.034409
# 3165     6.604509  0.946854  0.654196  ...  0.142056  0.209918  0.039506
# 3166     5.388298  0.950436  0.675470  ...  0.143659  0.172375  0.034483
# 3167     5.769115  0.938829  0.601529  ...  0.165509  0.185607  0.062257
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0     0.275862  0.007812  0.007812  0.007812  0.000000  0.000000      1
# 1     0.250000  0.009014  0.007812  0.054688  0.046875  0.052632      1
# 2     0.271186  0.007990  0.007812  0.015625  0.007812  0.046512      1
# 3     0.250000  0.201497  0.007812  0.562500  0.554688  0.247119      1
# 4     0.266667  0.712812  0.007812  5.484375  5.476562  0.208274      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 3163  0.262295  0.832899  0.007812  4.210938  4.203125  0.161929      0
# 3164  0.275862  0.909856  0.039062  3.679688  3.640625  0.277897      0
# 3165  0.275862  0.494271  0.007812  2.937500  2.929688  0.194759      0
# 3166  0.250000  0.791360  0.007812  3.593750  3.585938  0.311002      0
# 3167  0.271186  0.227022  0.007812  0.554688  0.546875  0.350000      0
#
# [3168 rows x 21 columns]

# %%
from pandas.core.groupby import DataFrameGroupBy
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
data = pd.DataFrame(min_max_scaler.fit_transform(data))
data = data.sample(frac=1)
data
# Out:
#             0         1         2         3         4         5         6   \
# 20    0.629914  0.604059  0.666381  0.484955  0.878095  0.465944  0.081716
# 2320  0.814904  0.333099  0.802668  0.796690  0.894081  0.157319  0.059571
# 1866  0.480352  0.725778  0.674643  0.174032  0.758412  0.673145  0.042081
# 2894  0.781008  0.192394  0.795692  0.764867  0.792105  0.091496  0.076684
# 1380  0.754346  0.388069  0.849581  0.601541  0.876501  0.343176  0.044069
# ...        ...       ...       ...       ...       ...       ...       ...
# 1126  0.744272  0.460326  0.737621  0.554583  0.940895  0.454460  0.065578
# 3100  0.587290  0.382761  0.625309  0.648209  0.631812  0.057319  0.165138
# 765   0.580720  0.411135  0.651709  0.404650  0.666162  0.343880  0.057411
# 733   0.572334  0.429367  0.628136  0.402462  0.672565  0.352366  0.042623
# 884   0.731238  0.406403  0.809641  0.551504  0.868276  0.387225  0.042019
#
#             7         8         9   ...        11        12        13  \
# 20    0.013774  0.767996  0.603187  ...  0.629914  0.208755  0.030819
# 2320  0.004998  0.550459  0.307424  ...  0.814904  0.734324  0.191881
# 1866  0.002671  0.834615  0.700012  ...  0.480352  0.651469  0.036279
# 2894  0.007012  0.432826  0.281157  ...  0.781008  0.653198  0.204102
# 1380  0.003458  0.641060  0.336618  ...  0.754346  0.413438  0.191407
# ...        ...       ...       ...  ...       ...       ...       ...
# 1126  0.005720  0.559855  0.302407  ...  0.744272  0.401187  0.215033
# 3100  0.031572  0.567378  0.525339  ...  0.587290  0.511143  0.052828
# 765   0.004395  0.751532  0.483825  ...  0.580720  0.221271  0.035916
# 733   0.002416  0.772336  0.541076  ...  0.572334  0.206385  0.068003
# 884   0.002759  0.671332  0.334144  ...  0.731238  0.393201  0.202799
#
#             14        15        16        17        18        19   20
# 20    0.550543  0.077314  0.006452  0.032523  0.032546  0.252119  1.0
# 2320  0.972570  0.538512  0.040860  0.549678  0.549356  0.108274  0.0
# 1866  0.904450  0.212050  0.006452  0.164046  0.164163  0.259537  0.0
# 2894  0.999749  0.268301  0.195699  0.276269  0.272532  0.081033  0.0
# 1380  0.999749  0.245746  0.040860  0.166905  0.166309  0.118471  1.0
# ...        ...       ...       ...       ...       ...       ...  ...
# 1126  0.990585  0.170331  0.040860  0.085418  0.084764  0.131238  1.0
# 3100  0.623068  0.232215  0.354839  0.179459  0.172344  0.309036  0.0
# 765   0.751054  0.134996  0.092473  0.159042  0.157368  0.166615  1.0
# 733   0.435644  0.102229  0.058065  0.151894  0.150930  0.118347  1.0
# 884   0.963717  0.418289  0.040860  0.432809  0.432403  0.138210  1.0
#
# [3168 rows x 21 columns]

# %%
X_train = data.iloc[:int(len(data)*0.7), :-1]  # матрица объекты-признаки
y_train = data.iloc[:int(len(data)*0.7), -1]  # истинные значения пола (мужчина/женщина)

X_test = data.iloc[int(len(data)*0.7):, :-1]  # матрица объекты-признаки
y_test = data.iloc[int(len(data)*0.7):, -1]  # истинные значения пола (мужчина/женщина)

# %%
# %%time

RANDOM_SEED = 42

neuron = Neuron()
neuron.fit(X_train.values, y_train.values, num_epochs=10000)
# Out:
# CPU times: user 6min 24s, sys: 5min 9s, total: 11min 34s
# Wall time: 6min 3s
# [0.6931471805599468,
#  0.6931513358010915,
#  0.6931559688612344,
#  0.6931610757351445,
#  0.6931666528135542,
#  0.6931726968468175,
#  0.6931792049112984,
#  0.6931861743782974,
#  0.6931936028853497,
#  0.693201488309715,
#  0.6932098287439225,
#  0.6932186224732347,
#  0.69322786795488,
#  0.6932375637989298,
#  0.6932477087507278,
#  0.6932583016747383,
#  0.6932693415397212,
#  0.693280827405137,
#  0.6932927584086942,
#  0.6933051337549716,
#  0.6933179527050026,
#  0.6933312145667877,
#  0.6933449186866453,
#  0.6933590644413434,
#  0.6933736512309614,
#  0.6933886784724196,
#  0.693404145593624,
#  0.6934200520281876,
#  0.6934363972106851,
#  0.6934531805723836,
#  0.6934704015374298,
#  0.6934880595194572,
#  0.693506153918562,
#  0.6935246841186452,
#  0.6935436494850636,
#  0.6935630493625851,
#  0.6935828830736189,
#  0.6936031499166843,
#  0.6936238491651234,
#  0.6936449800660001,
#  0.6936665418392179,
#  0.6936885336767896,
#  0.6937109547422713,
#  0.6937338041703485,
#  0.6937570810665407,
#  0.6937807845070356,
#  0.6938049135386184,
#  0.693829467178713,
#  0.6938544444154947,
#  0.6938798442080879,
#  0.6939056654868421,
#  0.6939319071536483,
#  0.6939585680823367,
#  0.6939856471190948,
#  0.6940131430829612,
#  0.6940410547663237,
#  0.6940693809354748,
#  0.6940981203311813,
#  0.6941272716692828,
#  0.6941568336413079,
#  0.6941868049151106,
#  0.6942171841355157,
#  0.6942479699249707,
#  0.6942791608842211,
#  0.6943107555929742,
#  0.6943427526105704,
#  0.6943751504766625,
#  0.6944079477118864,
#  0.6944411428185352,
#  0.694474734281223,
#  0.694508720567554,
#  0.6945431001287732,
#  0.6945778714004214,
#  0.6946130328029758,
#  0.694648582742483,
#  0.6946845196111815,
#  0.6947208417881208,
#  0.6947575476397573,
#  0.6947946355205572,
#  0.6948321037735665,
#  0.6948699507309906,
#  0.6949081747147459,
#  0.6949467740370074,
#  0.694985747000745,
#  0.6950250919002405,
#  0.6950648070215992,
#  0.6951048906432491,
#  0.6951453410364198,
#  0.6951861564656184,
#  0.6952273351890875,
#  0.6952688754592552,
#  0.6953107755231689,
#  0.6953530336229168,
#  0.6953956479960446,
#  0.6954386168759511,
#  0.6954819384922802,
#  0.6955256110712963,
#  0.6955696328362491,
#  0.6956140020077348,
#  0.6956587168040321,
#  0.6957037754414419,
#  0.6957491761346112,
#  0.6957949170968442,
#  0.6958409965404054,
#  0.6958874126768204,
#  0.6959341637171463,
#  0.6959812478722647,
#  0.696028663353133,
#  0.6960764083710533,
#  0.696124481137911,
#  0.696172879866423,
#  0.696221602770371,
#  0.6962706480648165,
#  0.6963200139663291,
#  0.6963696986931887,
#  0.6964197004655881,
#  0.696470017505833,
#  0.6965206480385229,
#  0.696571590290738,
#  0.6966228424922093,
#  0.6966744028754913,
#  0.6967262696761246,
#  0.6967784411327861,
#  0.6968309154874452,
#  0.696883690985509,
#  0.6969367658759557,
#  0.6969901384114777,
#  0.6970438068486042,
#  0.697097769447826,
#  0.6971520244737178,
#  0.6972065701950493,
#  0.6972614048848975,
#  0.6973165268207528,
#  0.6973719342846183,
#  0.69742762556311,
#  0.6974835989475446,
#  0.6975398527340377,
#  0.697596385223583,
#  0.6976531947221358,
#  0.6977102795406924,
#  0.6977676379953653,
#  0.697825268407456,
#  0.6978831691035232,
#  0.6979413384154463,
#  0.6979997746804915,
#  0.6980584762413704,
#  0.6981174414462993,
#  0.6981766686490477,
#  0.698236156208998,
#  0.6982959024911888,
#  0.698355905866364,
#  0.6984161647110195,
#  0.698476677407443,
#  0.6985374423437509,
#  0.6985984579139362,
#  0.6986597225178928,
#  0.6987212345614576,
#  0.6987829924564414,
#  0.6988449946206547,
#  0.6989072394779391,
#  0.6989697254581948,
#  0.6990324509974061,
#  0.69909541453766,
#  0.699158614527176,
#  0.6992220494203132,
#  0.6992857176776085,
#  0.6993496177657744,
#  0.6994137481577284,
#  0.6994781073326004,
#  0.6995426937757512,
#  0.6996075059787814,
#  0.6996725424395428,
#  0.6997378016621499,
#  0.6998032821569853,
#  0.6998689824407122,
#  0.6999349010362802,
#  0.7000010364729237,
#  0.7000673872861769,
#  0.7001339520178724,
#  0.7002007292161406,
#  0.7002677174354232,
#  0.700334915236459,
#  0.7004023211862943,
#  0.7004699338582837,
#  0.7005377518320804,
#  0.7006057736936413,
#  0.7006739980352223,
#  0.7007424234553744,
#  0.700811048558941,
#  0.7008798719570484,
#  0.7009488922671069,
#  0.7010181081128062,
#  0.7010875181240991,
#  0.701157120937202,
#  0.701226915194588,
#  0.7012968995449781,
#  0.7013670726433244,
#  0.7014374331508131,
#  0.7015079797348504,
#  0.7015787110690493,
#  0.7016496258332248,
#  0.7017207227133757,
#  0.7017920004016811,
#  0.7018634575964854,
#  0.7019350930022842,
#  0.7020069053297163,
#  0.7020788932955491,
#  0.7021510556226634,
#  0.7022233910400427,
#  0.7022958982827594,
#  0.7023685760919599,
#  0.7024414232148501,
#  0.7025144384046812,
#  0.7025876204207346,
#  0.7026609680283097,
#  0.7027344799987034,
#  0.7028081551091966,
#  0.7028819921430438,
#  0.7029559898894453,
#  0.703030147143543,
#  0.703104462706397,
#  0.7031789353849706,
#  0.7032535639921137,
#  0.7033283473465451,
#  0.7034032842728356,
#  0.7034783736013939,
#  0.703553614168441,
#  0.7036290048159991,
#  0.7037045443918752,
#  0.7037802317496344,
#  0.703856065748593,
#  0.7039320452537885,
#  0.7040081691359723,
#  0.7040844362715815,
#  0.7041608455427287,
#  0.704237395837177,
#  0.7043140860483226,
#  0.7043909150751795,
#  0.7044678818223536,
#  0.7045449852000321,
#  0.7046222241239545,
#  0.7046995975154016,
#  0.7047771043011725,
#  0.7048547434135638,
#  0.7049325137903539,
#  0.7050104143747781,
#  0.7050884441155139,
#  0.7051666019666613,
#  0.7052448868877147,
#  0.7053232978435549,
#  0.7054018338044197,
#  0.7054804937458932,
#  0.7055592766488719,
#  0.7056381814995621,
#  0.7057172072894425,
#  0.7057963530152573,
#  0.7058756176789902,
#  0.705955000287843,
#  0.7060344998542206,
#  0.7061141153957055,
#  0.7061938459350382,
#  0.7062736905001016,
#  0.7063536481238941,
#  0.7064337178445149,
#  0.7065138987051411,
#  0.7065941897540053,
#  0.7066745900443808,
#  0.706755098634554,
#  0.7068357145878108,
#  0.7069164369724139,
#  0.7069972648615805,
#  0.7070781973334613,
#  0.7071592334711266,
#  0.7072403723625377,
#  0.7073216131005324,
#  0.7074029547828018,
#  0.7074843965118722,
#  0.7075659373950801,
#  0.7076475765445581,
#  0.7077293130772109,
#  0.7078111461146961,
#  0.7078930747834007,
#  0.7079750982144285,
#  0.7080572155435689,
#  0.7081394259112909,
#  0.7082217284627067,
#  0.7083041223475659,
#  0.7083866067202261,
#  0.7084691807396354,
#  0.7085518435693151,
#  0.7086345943773369,
#  0.7087174323362999,
#  0.7088003566233193,
#  0.7088833664199988,
#  0.7089664609124101,
#  0.7090496392910814,
#  0.709132900750968,
#  0.7092162444914382,
#  0.7092996697162528,
#  0.7093831756335417,
#  0.7094667614557889,
#  0.7095504263998098,
#  0.7096341696867335,
#  0.7097179905419839,
#  0.7098018881952554,
#  0.7098858618804966,
#  0.7099699108358938,
#  0.7100540343038455,
#  0.7101382315309495,
#  0.7102225017679762,
#  0.7103068442698562,
#  0.7103912582956556,
#  0.7104757431085628,
#  0.7105602979758631,
#  0.7106449221689236,
#  0.7107296149631727,
#  0.7108143756380808,
#  0.7108992034771432,
#  0.7109840977678581,
#  0.7110690578017125,
#  0.7111540828741579,
#  0.7112391722845937,
#  0.7113243253363509,
#  0.7114095413366722,
#  0.7114948195966904,
#  0.7115801594314125,
#  0.7116655601597014,
#  0.7117510211042579,
#  0.7118365415916014,
#  0.7119221209520509,
#  0.712007758519705,
#  0.7120934536324316,
#  0.7121792056318405,
#  0.7122650138632698,
#  0.7123508776757675,
#  0.7124367964220744,
#  0.7125227694586007,
#  0.7126087961454204,
#  0.7126948758462384,
#  0.7127810079283821,
#  0.7128671917627827,
#  0.7129534267239555,
#  0.7130397121899834,
#  0.7131260475424983,
#  0.7132124321666685,
#  0.7132988654511724,
#  0.7133853467881874,
#  0.713471875573375,
#  0.7135584512058579,
#  0.7136450730882021,
#  0.7137317406264084,
#  0.7138184532298835,
#  0.7139052103114358,
#  0.7139920112872474,
#  0.7140788555768623,
#  0.7141657426031709,
#  0.7142526717923906,
#  0.7143396425740501,
#  0.7144266543809732,
#  0.7145137066492628,
#  0.7146007988182791,
#  0.7146879303306349,
#  0.714775100632164,
#  0.7148623091719202,
#  0.7149495554021483,
#  0.7150368387782783,
#  0.7151241587588986,
#  0.7152115148057524,
#  0.7152989063837089,
#  0.715386332960758,
#  0.715473794007988,
#  0.7155612889995735,
#  0.7156488174127571,
#  0.7157363787278346,
#  0.7158239724281402,
#  0.7159115980000302,
#  0.715999254932867,
#  0.716086942719007,
#  0.7161746608537802,
#  0.7162624088354757,
#  0.7163501861653325,
#  0.7164379923475173,
#  0.7165258268891126,
#  0.716613689300103,
#  0.716701579093356,
#  0.7167894957846088,
#  0.7168774388924588,
#  0.7169654079383397,
#  0.7170534024465133,
#  0.7171414219440534,
#  0.7172294659608295,
#  0.7173175340294958,
#  0.7174056256854683,
#  0.7174937404669245,
#  0.7175818779147742,
#  0.7176700375726608,
#  0.7177582189869288,
#  0.7178464217066243,
#  0.7179346452834764,
#  0.7180228892718791,
#  0.7181111532288844,
#  0.7181994367141843,
#  0.7182877392900939,
#  0.7183760605215476,
#  0.7184643999760745,
#  0.7185527572237883,
#  0.7186411318373808,
#  0.7187295233920952,
#  0.7188179314657233,
#  0.7189063556385866,
#  0.7189947954935294,
#  0.7190832506158944,
#  0.7191717205935195,
#  0.719260205016722,
#  0.7193487034782822,
#  0.7194372155734337,
#  0.7195257408998506,
#  0.7196142790576315,
#  0.7197028296492896,
#  0.719791392279737,
#  0.7198799665562774,
#  0.7199685520885866,
#  0.7200571484887034,
#  0.7201457553710184,
#  0.7202343723522568,
#  0.7203229990514736,
#  0.7204116350900305,
#  0.7205002800915938,
#  0.7205889336821164,
#  0.7206775954898271,
#  0.7207662651452168,
#  0.7208549422810304,
#  0.7209436265322517,
#  0.7210323175360916,
#  0.7211210149319746,
#  0.7212097183615306,
#  0.7212984274685835,
#  0.7213871418991313,
#  0.7214758613013477,
#  0.7215645853255566,
#  0.7216533136242289,
#  0.7217420458519728,
#  0.7218307816655122,
#  0.7219195207236865,
#  0.7220082626874306,
#  0.7220970072197693,
#  0.7221857539858061,
#  0.7222745026527034,
#  0.7223632528896855,
#  0.7224520043680134,
#  0.7225407567609857,
#  0.7226295097439164,
#  0.722718262994135,
#  0.7228070161909631,
#  0.7228957690157207,
#  0.7229845211516958,
#  0.7230732722841491,
#  0.723162022100295,
#  0.7232507702892926,
#  0.7233395165422428,
#  0.7234282605521599,
#  0.72351700201398,
#  0.7236057406245403,
#  0.7236944760825715,
#  0.7237832080886883,
#  0.7238719363453769,
#  0.7239606605569853,
#  0.7240493804297136,
#  0.7241380956716079,
#  0.7242268059925427,
#  0.7243155111042127,
#  0.7244042107201313,
#  0.7244929045556077,
#  0.7245815923277485,
#  0.7246702737554375,
#  0.7247589485593376,
#  0.7248476164618698,
#  0.7249362771872119,
#  0.7250249304612827,
#  0.7251135760117364,
#  0.7252022135679547,
#  0.7252908428610305,
#  0.7253794636237639,
#  0.7254680755906536,
#  0.7255566784978854,
#  0.7256452720833192,
#  0.7257338560864859,
#  0.7258224302485787,
#  0.7259109943124372,
#  0.7259995480225463,
#  0.7260880911250196,
#  0.7261766233675944,
#  0.7262651444996258,
#  0.7263536542720711,
#  0.7264421524374854,
#  0.7265306387500111,
#  0.7266191129653732,
#  0.7267075748408617,
#  0.7267960241353297,
#  0.7268844606091884,
#  0.7269728840243872,
#  0.7270612941444147,
#  0.7271496907342881,
#  0.7272380735605397,
#  0.7273264423912156,
#  0.7274147969958634,
#  0.727503137145528,
#  0.7275914626127323,
#  0.7276797731714845,
#  0.7277680685972587,
#  0.7278563486669893,
#  0.727944613159064,
#  0.7280328618533215,
#  0.728121094531027,
#  0.7282093109748863,
#  0.7282975109690158,
#  0.7283856942989536,
#  0.7284738607516353,
#  0.7285620101154033,
#  0.7286501421799817,
#  0.7287382567364817,
#  0.7288263535773872,
#  0.7289144324965503,
#  0.7290024932891791,
#  0.729090535751836,
#  0.7291785596824272,
#  0.7292665648801959,
#  0.7293545511457135,
#  0.729442518280875,
#  0.729530466088888,
#  0.7296183943742669,
#  0.7297063029428281,
#  0.72979419160168,
#  0.7298820601592165,
#  0.7299699084251063,
#  0.7300577362102975,
#  0.7301455433269931,
#  0.7302333295886585,
#  0.7303210948100064,
#  0.7304088388069959,
#  0.7304965613968186,
#  0.7305842623978975,
#  0.7306719416298764,
#  0.7307595989136169,
#  0.7308472340711865,
#  0.730934846925856,
#  0.7310224373020926,
#  0.7311100050255501,
#  0.7311975499230645,
#  0.7312850718226466,
#  0.7313725705534787,
#  0.7314600459459032,
#  0.7315474978314178,
#  0.7316349260426699,
#  0.7317223304134501,
#  0.7318097107786838,
#  0.7318970669744294,
#  0.731984398837867,
#  0.7320717062072934,
#  0.732158988922115,
#  0.7322462468228507,
#  0.7323334797511084,
#  0.7324206875495948,
#  0.7325078700621026,
#  0.7325950271334993,
#  0.7326821586097327,
#  0.7327692643378184,
#  0.7328563441658311,
#  0.7329433979429039,
#  0.7330304255192174,
#  0.7331174267459993,
#  0.7332044014755186,
#  0.7332913495610708,
#  0.733378270856982,
#  0.7334651652185972,
#  0.7335520325022805,
#  0.7336388725654028,
#  0.7337256852663389,
#  0.7338124704644631,
#  0.7338992280201416,
#  0.7339859577947303,
#  0.7340726596505628,
#  0.7341593334509506,
#  0.734245979060177,
#  0.7343325963434871,
#  0.7344191851670903,
#  0.7345057453981466,
#  0.7345922769047647,
#  0.7346787795560006,
#  0.7347652532218447,
#  0.7348516977732237,
#  0.7349381130819868,
#  0.7350244990209124,
#  0.7351108554636901,
#  0.7351971822849261,
#  0.7352834793601306,
#  0.7353697465657165,
#  0.7354559837789942,
#  0.7355421908781653,
#  0.7356283677423159,
#  0.7357145142514191,
#  0.7358006302863201,
#  0.7358867157287335,
#  0.7359727704612501,
#  0.7360587943673121,
#  0.7361447873312247,
#  0.7362307492381427,
#  0.736316679974071,
#  0.7364025794258562,
#  0.7364884474811806,
#  0.7365742840285595,
#  0.7366600889573404,
#  0.7367458621576894,
#  0.7368316035205966,
#  0.7369173129378622,
#  0.7370029903020999,
#  0.7370886355067248,
#  0.7371742484459558,
#  0.7372598290148047,
#  0.7373453771090791,
#  0.7374308926253708,
#  0.7375163754610541,
#  0.7376018255142824,
#  0.7376872426839822,
#  0.7377726268698502,
#  0.7378579779723482,
#  0.7379432958926972,
#  0.7380285805328773,
#  0.7381138317956193,
#  0.7381990495843987,
#  0.7382842338034405,
#  0.7383693843577047,
#  0.738454501152889,
#  0.7385395840954205,
#  0.7386246330924524,
#  0.738709648051865,
#  0.7387946288822503,
#  0.7388795754929217,
#  0.738964487793899,
#  0.7390493656959086,
#  0.7391342091103824,
#  0.7392190179494466,
#  0.7393037921259256,
#  0.7393885315533305,
#  0.7394732361458647,
#  0.7395579058184076,
#  0.7396425404865216,
#  0.7397271400664435,
#  0.7398117044750797,
#  0.7398962336300069,
#  0.7399807274494615,
#  0.7400651858523432,
#  0.740149608758204,
#  0.740233996087252,
#  0.7403183477603428,
#  0.740402663698973,
#  0.7404869438252851,
#  0.7405711880620578,
#  0.7406553963327019,
#  0.7407395685612623,
#  0.7408237046724059,
#  0.7409078045914261,
#  0.7409918682442355,
#  0.7410758955573605,
#  0.7411598864579413,
#  0.7412438408737272,
#  0.741327758733076,
#  0.7414116399649409,
#  0.7414954844988805,
#  0.7415792922650418,
#  0.7416630631941732,
#  0.7417467972176024,
#  0.7418304942672452,
#  0.7419141542756019,
#  0.7419977771757473,
#  0.7420813629013333,
#  0.7421649113865846,
#  0.7422484225662922,
#  0.7423318963758126,
#  0.7424153327510674,
#  0.7424987316285334,
#  0.742582092945245,
#  0.742665416638789,
#  0.7427487026473024,
#  0.7428319509094653,
#  0.742915161364504,
#  0.7429983339521837,
#  0.7430814686128054,
#  0.7431645652872068,
#  0.7432476239167535,
#  0.74333064444334,
#  0.7434136268093852,
#  0.7434965709578306,
#  0.7435794768321339,
#  0.7436623443762714,
#  0.7437451735347322,
#  0.7438279642525106,
#  0.743910716475115,
#  0.743993430148552,
#  0.7440761052193309,
#  0.7441587416344612,
#  0.7442413393414451,
#  0.7443238982882788,
#  0.744406418423448,
#  0.7444888996959249,
#  0.7445713420551656,
#  0.7446537454511074,
#  0.7447361098341696,
#  0.7448184351552407,
#  0.7449007213656891,
#  0.7449829684173482,
#  0.7450651762625219,
#  0.7451473448539782,
#  0.7452294741449479,
#  0.7453115640891214,
#  0.7453936146406446,
#  0.7454756257541187,
#  0.7455575973845977,
#  0.7456395294875822,
#  0.7457214220190247,
#  0.7458032749353128,
#  0.7458850881932849,
#  0.7459668617502117,
#  0.7460485955638029,
#  0.7461302895922003,
#  0.7462119437939836,
#  0.7462935581281479,
#  0.7463751325541286,
#  0.7464566670317773,
#  0.7465381615213701,
#  0.7466196159835985,
#  0.7467010303795754,
#  0.7467824046708249,
#  0.7468637388192828,
#  0.7469450327872965,
#  0.7470262865376179,
#  0.747107500033405,
#  0.7471886732382175,
#  0.7472698061160152,
#  0.7473508986311569,
#  0.7474319507483956,
#  0.7475129624328762,
#  0.747593933650137,
#  0.7476748643661064,
#  0.747755754547093,
#  0.7478366041597933,
#  0.7479174131712869,
#  0.7479981815490299,
#  0.7480789092608602,
#  0.7481595962749852,
#  0.7482402425599908,
#  0.7483208480848303,
#  0.7484014128188254,
#  0.7484819367316713,
#  0.7485624197934169,
#  0.7486428619744832,
#  0.748723263245644,
#  0.7488036235780364,
#  0.7488839429431521,
#  0.748964221312836,
#  0.7490444586592856,
#  0.7491246549550484,
#  0.7492048101730203,
#  0.749284924286442,
#  0.7493649972688972,
#  0.749445029094315,
#  0.7495250197369611,
#  0.7496049691714419,
#  0.7496848773726945,
#  0.7497647443159963,
#  0.7498445699769527,
#  0.7499243543315006,
#  0.7500040973559042,
#  0.7500837990267577,
#  0.7501634593209727,
#  0.7502430782157876,
#  0.7503226556887622,
#  0.7504021917177736,
#  0.7504816862810142,
#  0.7505611393569936,
#  0.7506405509245335,
#  0.7507199209627669,
#  0.7507992494511375,
#  0.7508785363693944,
#  0.7509577816975959,
#  0.7510369854160998,
#  0.7511161475055708,
#  0.7511952679469698,
#  0.7512743467215605,
#  0.7513533838109003,
#  0.7514323791968444,
#  0.7515113328615399,
#  0.7515902447874276,
#  0.7516691149572349,
#  0.7517479433539794,
#  0.751826729960967,
#  0.7519054747617888,
#  0.751984177740312,
#  0.7520628388806987,
#  0.7521414581673782,
#  0.7522200355850651,
#  0.752298571118748,
#  0.7523770647536921,
#  0.752455516475436,
#  0.7525339262697888,
#  0.7526122941228306,
#  0.7526906200209125,
#  0.7527689039506463,
#  0.7528471458989172,
#  0.7529253458528697,
#  0.7530035037999091,
#  0.7530816197277057,
#  0.7531596936241879,
#  0.7532377254775399,
#  0.7533157152762036,
#  0.753393663008876,
#  0.7534715686645053,
#  0.7535494322322931,
#  0.7536272537016916,
#  0.7537050330624002,
#  0.7537827703043662,
#  0.7538604654177826,
#  0.7539381183930879,
#  0.7540157292209589,
#  0.7540932978923217,
#  0.7541708243983346,
#  0.7542483087303993,
#  0.7543257508801527,
#  0.7544031508394681,
#  0.7544805086004511,
#  0.7545578241554438,
#  0.7546350974970156,
#  0.7547123286179709,
#  0.7547895175113379,
#  0.7548666641703771,
#  0.7549437685885712,
#  0.7550208307596279,
#  0.7550978506774807,
#  0.755174828336284,
#  0.7552517637304111,
#  0.7553286568544565,
#  0.755405507703232,
#  0.7554823162717685,
#  0.7555590825553088,
#  0.7556358065493121,
#  0.7557124882494478,
#  0.7557891276516016,
#  0.7558657247518659,
#  0.7559422795465426,
#  0.7560187920321418,
#  0.7560952622053798,
#  0.7561716900631792,
#  0.7562480756026677,
#  0.7563244188211711,
#  0.7564007197162222,
#  0.7564769782855512,
#  0.7565531945270878,
#  0.7566293684389603,
#  0.7567055000194944,
#  0.7567815892672092,
#  0.7568576361808222,
#  0.756933640759239,
#  0.7570096030015601,
#  0.7570855229070783,
#  0.7571614004752726,
#  0.7572372357058138,
#  0.7573130285985594,
#  0.7573887791535503,
#  0.7574644873710185,
#  0.7575401532513732,
#  0.7576157767952121,
#  0.7576913580033113,
#  0.7577668968766289,
#  0.7578423934163037,
#  0.7579178476236519,
#  0.757993259500166,
#  0.7580686290475172,
#  0.7581439562675502,
#  0.7582192411622831,
#  0.7582944837339131,
#  0.7583696839848,
#  0.7584448419174815,
#  0.7585199575346638,
#  0.7585950308392212,
#  0.7586700618341976,
#  0.7587450505228005,
#  0.7588199969084053,
#  0.7588949009945545,
#  0.7589697627849491,
#  0.7590445822834574,
#  0.7591193594941087,
#  0.7591940944210931,
#  0.759268787068758,
#  0.7593434374416106,
#  0.7594180455443207,
#  0.7594926113817071,
#  0.7595671349587502,
#  0.7596416162805851,
#  0.7597160553524975,
#  0.7597904521799295,
#  0.7598648067684731,
#  0.7599391191238736,
#  0.760013389252023,
#  0.7600876171589648,
#  0.7601618028508922,
#  0.7602359463341455,
#  0.7603100476152053,
#  0.7603841067007089,
#  0.7604581235974295,
#  0.7605320983122875,
#  0.7606060308523435,
#  0.7606799212248043,
#  0.760753769437014,
#  0.760827575496461,
#  0.7609013394107679,
#  0.7609750611876994,
#  0.7610487408351586,
#  0.7611223783611801,
#  0.7611959737739397,
#  0.7612695270817459,
#  0.7613430382930427,
#  0.761416507416404,
#  0.7614899344605413,
#  0.7615633194342957,
#  0.7616366623466356,
#  0.7617099632066643,
#  0.7617832220236118,
#  0.7618564388068363,
#  0.7619296135658253,
#  0.7620027463101909,
#  0.7620758370496733,
#  0.7621488857941368,
#  0.7622218925535675,
#  0.7622948573380783,
#  0.7623677801579052,
#  0.7624406610234042,
#  0.7625134999450544,
#  0.7625862969334525,
#  0.762659051999316,
#  0.7627317651534815,
#  0.7628044364069066,
#  0.7628770657706617,
#  0.7629496532559362,
#  0.7630221988740347,
#  0.7630947026363767,
#  0.7631671645544965,
#  0.7632395846400422,
#  0.7633119629047747,
#  0.7633842993605658,
#  0.7634565940194012,
#  0.7635288468933754,
#  0.7636010579946945,
#  0.7636732273356721,
#  0.7637453549287309,
#  0.7638174407864022,
#  0.7638894849213228,
#  0.7639614873462391,
#  0.7640334480740011,
#  0.7641053671175626,
#  0.7641772444899863,
#  0.7642490802044312,
#  0.7643208742741707,
#  0.7643926267125675,
#  0.7644643375330961,
#  0.7645360067493254,
#  0.7646076343749301,
#  0.7646792204236816,
#  0.7647507649094487,
#  0.7648222678462031,
#  0.764893729248011,
#  0.7649651491290366,
#  0.7650365275035397,
#  0.7651078643858794,
#  0.7651791597905051,
#  0.7652504137319618,
#  0.7653216262248929,
#  0.7653927972840313,
#  0.7654639269242001,
#  0.7655350151603219,
#  0.7656060620074018,
#  0.7656770674805446,
#  0.7657480315949402,
#  0.7658189543658663,
#  0.7658898358086953,
#  0.7659606759388824,
#  0.7660314747719762,
#  0.7661022323236079,
#  0.766172948609498,
#  0.7662436236454515,
#  0.7663142574473599,
#  0.7663848500311985,
#  0.7664554014130299,
#  0.7665259116089952,
#  0.7665963806353249,
#  0.7666668085083269,
#  0.7667371952443952,
#  0.7668075408599989,
#  0.7668778453716988,
#  0.7669481087961252,
#  0.7670183311499956,
#  ...]

# %%
sk_perceptron = skPerceptron(random_state=RANDOM_SEED, max_iter=10000)
sk_perceptron.fit(X_train.values, y_train.values)
# Out:
# Perceptron(max_iter=10000, random_state=42)

# %%
print('Точность нашего перцептрона: {:.3f}%'.format(
    accuracy_score(y_test.values, np.array(neuron.forward_pass(X_test.values) > 0.5).ravel()) * 100))
print('Точность перцептрона из sklearn: {:.3f}%'.format(
    accuracy_score(y_test.values, sk_perceptron.predict(X_test.values)) * 100))
# Out:
# Точность нашего перцептрона: 95.058%
# Точность перцептрона из sklearn: 98.107%
